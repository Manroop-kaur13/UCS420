# %%
#que1

# %%
roll_number=1024170049
l=[]
while roll_number>0:
    tba=roll_number%10
    roll_number=roll_number//10
    l.append(tba*10)
l.reverse()
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90]

# %%
#(i)
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90]

# %%
#(ii)
l.append(30)
print(l)
l.insert(2,80)
print(l)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90, 30]
# [10, 0, 80, 20, 40, 10, 70, 0, 0, 40, 90, 30]

# %%
#(iii)
l.pop()
print(l)
l.remove(80)
print(l)
# Out:
# [10, 0, 80, 20, 40, 10, 70, 0, 0, 40, 90]
# [10, 0, 20, 40, 10, 70, 0, 0, 40, 90]

# %%
#(iv)
l2=[i for i in l]
l2.sort()
print(l2)
l2.sort(reverse=True)
print(l2)
# Out:
# [0, 0, 0, 10, 10, 20, 40, 40, 70, 90]
# [90, 70, 40, 40, 20, 10, 10, 0, 0, 0]

# %%
#(v)
print(l[0:3])
print(l[-1:-4:-1])
# Out:
# [90, 70, 40]
# [0, 0, 0]

# %%
#(vi)
avg_l=sum(l)/len(l)
new_l=[i for i in l if i>avg_l]
print(new_l)
# Out:
# [90, 70, 40, 40]

# %%
#que 2

# %%
scores=tuple(l[0:8])
print(scores)
# Out:
# (90, 70, 40, 40, 20, 10, 10, 0)

# %%
#(i)
max_score=max(scores)
min_score=min(scores)
print("maximum score is",max_score)
print("maximum score index is",scores.index(max_score))
print("minimum score is",min_score)
print("frequency of minimum score is",scores.count(min_score))
# Out:
# maximum score is 90
# maximum score index is 0
# minimum score is 0
# frequency of minimum score is 1

# %%
#(ii)
l_scores=list(scores)
l_scores=l_scores[-1::-1]
print(l_scores)
# Out:
# [0, 10, 10, 20, 40, 40, 70, 90]

# %%
print("scores tupple is",scores)
num=int(input("Enter a score"))
if(num in scores):
    print(scores.index(num))
    
else:
    print("not present")
# Out:
# scores tupple is (90, 70, 40, 40, 20, 10, 10, 0)
# Enter a score 50
# not present

# %%
scores[4]=90
print(scores)

#It is because tupples are immutuable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 scores[4]=90
#       2 print(scores)
#
# TypeError: 'tuple' object does not support item assignment

# %%
first_score,second_score,*all_remaining_scores=scores
print(first_score)
print(second_score)
print(all_remaining_scores)
# Out:
# 90
# 70
# [40, 40, 20, 10, 10, 0]

# %%
#que5

# %%
my_dict = { "name": "Manroop Kaur", "roll_no": "1024170049", "branch": "COPC", "age": 20, "city": "Kurukshetra" }
print(my_dict)
# Out:
# {'name': 'Manroop Kaur', 'roll_no': '1024170049', 'branch': 'COPC', 'age': 20, 'city': 'Kurukshetra'}

# %%
my_dict["Location"]=my_dict.pop("city")
print(my_dict)
# Out:
# {'name': 'Manroop Kaur', 'roll_no': '1024170049', 'branch': 'COPC', 'age': 20, 'Location': 'Kurukshetra'}

# %%
my_dict["CGPA"]=9.5
print(my_dict)
# Out:
# {'name': 'Manroop Kaur', 'roll_no': '1024170049', 'branch': 'COPC', 'age': 20, 'Location': 'Kurukshetra', 'CGPA': 9.5}

# %%
my_dict["age"]=my_dict["age"]+1;
print(my_dict)
# Out:
# {'name': 'Manroop Kaur', 'roll_no': '1024170049', 'branch': 'COPC', 'age': 21, 'Location': 'Kurukshetra', 'CGPA': 9.5}

# %%
del_pop=my_dict.copy()
del_pop.pop("branch")
print(del_pop)
# Out:
# {'name': 'Manroop Kaur', 'roll_no': '1024170049', 'age': 21, 'Location': 'Kurukshetra', 'CGPA': 9.5}

# %%
del_del=my_dict.copy()
del(del_del["branch"])
print(del_del)
# Out:
# {'name': 'Manroop Kaur', 'roll_no': '1024170049', 'age': 21, 'Location': 'Kurukshetra', 'CGPA': 9.5}

# %%
for key, value in my_dict.items():
    print(key,"-->", value)
# Out:
# name --> Manroop Kaur
# roll_no --> 1024170049
# branch --> COPC
# age --> 21
# Location --> Kurukshetra
# CGPA --> 9.5

# %%
if("email"in my_dict):
    print(my_dict["email"])
else:
    print("does not exist")
# Out:
# does not exist

# %%
friend_dict={ "name": "Avneet Kaur", "roll_no": "1024170050", "branch": "COPC", "age": 20, "Location": "Patiala" }
print(friend_dict)
# Out:
# {'name': 'Avneet Kaur', 'roll_no': '1024170050', 'branch': 'COPC', 'age': 20, 'Location': 'Patiala'}

# %%
merged_dict={**my_dict,**friend_dict}
print(merged_dict)
# Out:
# {'name': 'Avneet Kaur', 'roll_no': '1024170050', 'branch': 'COPC', 'age': 20, 'Location': 'Patiala', 'CGPA': 9.5}

# %%
new_dict={key:value for (key,value) in my_dict.items() if(type(value)==str)}
print(new_dict)
# Out:
# {'name': 'Manroop Kaur', 'roll_no': '1024170049', 'branch': 'COPC', 'Location': 'Kurukshetra'}

# %%
#que 3
import random
random.seed(1024170049)

# %%
numbers=[random.randint(100,900) for i in range(100)]
print(numbers)
# Out:
# [693, 784, 418, 600, 899, 394, 402, 757, 516, 269, 611, 627, 650, 770, 513, 115, 748, 360, 354, 366, 427, 673, 357, 715, 469, 716, 367, 513, 533, 451, 212, 709, 732, 512, 103, 484, 886, 199, 491, 111, 383, 690, 113, 812, 235, 634, 453, 688, 118, 503, 597, 354, 234, 679, 511, 206, 734, 778, 361, 711, 581, 106, 605, 830, 516, 398, 613, 383, 497, 857, 381, 656, 188, 586, 238, 560, 652, 117, 311, 164, 558, 283, 393, 185, 115, 771, 689, 591, 501, 236, 311, 632, 166, 512, 869, 427, 105, 805, 586, 265]

# %%
odd_num=[i for i in numbers if i%2!=0]
print(odd_num)
print("count is:", len(odd_num))
# Out:
# [693, 899, 757, 269, 611, 627, 513, 115, 427, 673, 357, 715, 469, 367, 513, 533, 451, 709, 103, 199, 491, 111, 383, 113, 235, 453, 503, 597, 679, 511, 361, 711, 581, 605, 613, 383, 497, 857, 381, 117, 311, 283, 393, 185, 115, 771, 689, 591, 501, 311, 869, 427, 105, 805, 265]
# count is: 55

# %%
even_num=[i for i in numbers if i%2==0]
print(even_num)
print("count is:", len(even_num))
# Out:
# [784, 418, 600, 394, 402, 516, 650, 770, 748, 360, 354, 366, 716, 212, 732, 512, 484, 886, 690, 812, 634, 688, 118, 354, 234, 206, 734, 778, 106, 830, 516, 398, 656, 188, 586, 238, 560, 652, 164, 558, 236, 632, 166, 512, 586]
# count is: 45

# %%
def prime(i):
    isprime=True
    if i<2:
        isprime=False
        return isprime
    for j in range(2,(i//2)+1,1):
        if i%j==0:
            isprime=False
    return isprime
prime_number=[k for k in numbers if prime(k)]
print(prime_number)
print("count is:",len(prime_number))
# Out:
# [757, 269, 673, 367, 709, 103, 199, 491, 383, 113, 503, 613, 383, 857, 311, 283, 311]
# count is: 17

# %%
most_frequent = max(set(numbers), key=numbers.count)
print("Most frequent number:", most_frequent)
print("Frequency:", numbers.count(most_frequent))
# Out:
# Most frequent number: 512
# Frequency: 2

# %%
#que 4
roll_num=set()
num=1024170049
while num>0:
    tba=num%10
    num=num//10
    roll_num.add(tba)
print(roll_num)
# Out:
# {0, 1, 2, 4, 7, 9}

# %%
A={i*7 for i in roll_num}
B={i*9 for i in roll_num}
print(A)
print(B)
# Out:
# {0, 7, 14, 49, 28, 63}
# {0, 36, 9, 81, 18, 63}

# %%
print(A.union(B))
# Out:
# {0, 36, 7, 9, 14, 49, 81, 18, 28, 63}

# %%
print(A.intersection(B))
# Out:
# {0, 63}

# %%
print(A.difference(B))
print(B.difference(A))
# Out:
# {49, 28, 14, 7}
# {81, 9, 18, 36}

# %%
print(A.symmetric_difference(B))
# Out:
# {7, 9, 14, 81, 18, 28, 36, 49}

# %%
print(A.issubset(B))
print(B.issuperset(A))
# Out:
# False
# False

# %%
X=int(input("Enter number to be removed"))
A.discard(X)
